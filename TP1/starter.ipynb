# %%
import numpy as np
import os.path
from time import time
import types
import matplotlib.pyplot as plt

#import my_functions

# %% [markdown]
# # Nouvelle section

# %%
# %matplotlib inline
# edit this line to change the figure size
plt.rcParams['figure.figsize'] = (16.0, 10.0)
# force auto-reload of import modules before running code 
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
I = plt . imread ('/content/drive/MyDrive/Colab Notebooks/BTI-main/figs/red_bird.png')
(I . shape ) # Afficher sa taille
# Out:
# (152, 204, 3)

# %%
from view_surface import * # importera toutes les fonctions du fichier view_surface .py
view_surface ('/content/drive/MyDrive/Colab Notebooks/BTI-main/figs/flower.png')

# %%
from my_functions import * # importera toutes les fonctions du fichier view_surface .py
OpenImage ('/content/drive/MyDrive/Colab Notebooks/BTI-main/figs/flower.png')
